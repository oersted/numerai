# %% [markdown]
# # Auto-sklearn classifier

# %% [markdown]
# ## Setup

# %%
import pickle
import pandas as pd

# %%
from autosklearn.classification import AutoSklearnClassifier
from autosklearn.metrics import log_loss

# %%
import sys
sys.path.append('..')
from utils import *

# %%
x_train, y_train, eras_train = train_data(weras=True)
x_val, y_val = val_data()
bl = baseline(x_train, y_train, x_val, y_val)
bl
# Out:
# 0.69245942891354983

# %% [markdown]
# ## First try

# %% [markdown]
# ### Training

# %%
model = AutoSklearnClassifier(
    resampling_strategy='cv',
    resampling_strategy_arguments={'folds': 3},
    tmp_folder='autosklearn/classifier/tmp/',
    output_folder='autosklearn/classifier/out/',
    delete_tmp_folder_after_terminate=False,
    delete_output_folder_after_terminate=False,
    shared_mode=True,
)

# %%
# model.fit(x_train, y_train, metric=log_loss, dataset_name='numerai')

# %%
# with open('autosklearn/classifier/model.pkl', 'wb') as auto_sklearn_file:
#      pickle.dump(model, auto_sklearn_file)

# %% [markdown]
# ### Testing

# %%
with open('autosklearn/classifier/model.pkl', 'rb') as auto_sklearn_file:
     model = pickle.load(auto_sklearn_file)

# %%
print(model.show_models())
# Out:
# [(0.860000, MyDummyClassifier(configuration=1, init_params=None, random_state=None)),
# (0.140000, SimpleClassificationPipeline({'preprocessor:feature_agglomeration:linkage': 'complete', 'balancing:strategy': 'none', 'preprocessor:feature_agglomeration:affinity': 'manhattan', 'classifier:__choice__': 'gaussian_nb', 'one_hot_encoding:use_minimum_fraction': 'False', 'preprocessor:__choice__': 'feature_agglomeration', 'preprocessor:feature_agglomeration:n_clusters': 298, 'imputation:strategy': 'mean', 'rescaling:__choice__': 'standardize', 'preprocessor:feature_agglomeration:pooling_func': 'max'},
# dataset_properties={
#   'signed': False,
#   'sparse': False,
#   'task': 1,
#   'multiclass': False,
#   'multilabel': False,
#   'target_type': 'classification'})),
# ]

# %% [markdown]
# Most of the weight is given to a model called DummyClassifier. Never a good sign :). I guess it makes sense due to the random nature of the dataset. It's mostly noise with a small modifier.
#
# The actual chosen classifier is GaussianNB with an Agglomerative Clustering preprocessor.

# %% [markdown]
# Apparently, prediction is not supported when doing CV.

# %%
model.resampling_strategy = 'holdout'
model.refit(x_train, y_train)
validate(y_train, model.predict_proba(x_train))
# Out:
# 0.69198138057469816

# %% [markdown]
# Surprisingly, 0.691 is better that what I'm getting from the TPoT preliminary results. The current best is on 0.692 and uses LogReg with some RDF preprocessing.

# %%
pd.DataFrame(model.cv_results_)
# Out:
#     mean_fit_time  mean_test_score param_balancing:strategy  \
# 0      292.189848     0.000000e+00                     none
# 1      360.019453    -2.147484e+09                     none
# 2      360.014553    -2.147484e+09                     none
# 3        1.106124     0.000000e+00                     none
# 4      360.014503    -2.147484e+09                     none
# 5      360.019212     0.000000e+00                     none
# 6      184.322468     0.000000e+00                     none
# 7      239.021570    -2.147484e+09                weighting
# 8      111.881840     0.000000e+00                     none
# 9      360.017498    -2.147484e+09                     none
# 10     360.107608     0.000000e+00                     none
# 11      16.225919    -7.424151e-01                     none
# 12       8.995242     0.000000e+00                weighting
# 13     360.098289     0.000000e+00                     none
# 14     196.074019     0.000000e+00                     none
#
#    param_classifier:__choice__  param_classifier:adaboost:algorithm  \
# 0                random_forest                                  NaN
# 1                random_forest                                  NaN
# 2                random_forest                                  NaN
# 3                          sgd                                  NaN
# 4                random_forest                                  NaN
# 5                  extra_trees                                  NaN
# 6                  extra_trees                                  NaN
# 7                   libsvm_svc                                  NaN
# 8                random_forest                                  NaN
# 9                   libsvm_svc                                  NaN
# 10               random_forest                                  NaN
# 11                 gaussian_nb                                  NaN
# 12                         sgd                                  NaN
# 13                 extra_trees                                  NaN
# 14               random_forest                                  NaN
#
#     param_classifier:adaboost:learning_rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
#
#     param_classifier:adaboost:max_depth  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
#
#     param_classifier:adaboost:n_estimators  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
#
#     param_classifier:bernoulli_nb:alpha  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
#
#     param_classifier:bernoulli_nb:fit_prior   ...     \
# 0                                       NaN   ...
# 1                                       NaN   ...
# 2                                       NaN   ...
# 3                                       NaN   ...
# 4                                       NaN   ...
# 5                                       NaN   ...
# 6                                       NaN   ...
# 7                                       NaN   ...
# 8                                       NaN   ...
# 9                                       NaN   ...
# 10                                      NaN   ...
# 11                                      NaN   ...
# 12                                      NaN   ...
# 13                                      NaN   ...
# 14                                      NaN   ...
#
#     param_preprocessor:random_trees_embedding:n_estimators  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                              100.0
# 13                                                NaN
# 14                                                NaN
#
#     param_preprocessor:select_percentile_classification:percentile  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     param_preprocessor:select_percentile_classification:score_func  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     param_preprocessor:select_rates:alpha  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
#
#     param_preprocessor:select_rates:mode  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
#
#     param_preprocessor:select_rates:score_func  param_rescaling:__choice__  \
# 0                                          NaN                 standardize
# 1                                          NaN                 standardize
# 2                                          NaN                 standardize
# 3                                          NaN                        none
# 4                                          NaN                   normalize
# 5                                          NaN                   normalize
# 6                                          NaN                 standardize
# 7                                          NaN                        none
# 8                                          NaN                        none
# 9                                          NaN                      minmax
# 10                                         NaN                 standardize
# 11                                         NaN                 standardize
# 12                                         NaN                 standardize
# 13                                         NaN                        none
# 14                                         NaN                        none
#
#                                                params rank_test_scores  \
# 0   {'classifier:random_forest:max_depth': 'None',...                1
# 1   {'classifier:random_forest:max_depth': 'None',...               11
# 2   {'classifier:random_forest:max_depth': 'None',...               11
# 3   {'classifier:sgd:n_iter': 20, 'one_hot_encodin...                1
# 4   {'classifier:random_forest:max_depth': 'None',...               11
# 5   {'one_hot_encoding:use_minimum_fraction': 'Tru...                1
# 6   {'one_hot_encoding:use_minimum_fraction': 'Tru...                1
# 7   {'one_hot_encoding:use_minimum_fraction': 'Fal...               11
# 8   {'classifier:random_forest:max_depth': 'None',...                1
# 9   {'classifier:__choice__': 'libsvm_svc', 'class...               11
# 10  {'classifier:random_forest:max_depth': 'None',...                1
# 11  {'preprocessor:feature_agglomeration:linkage':...               10
# 12  {'preprocessor:random_trees_embedding:n_estima...                1
# 13  {'one_hot_encoding:use_minimum_fraction': 'Tru...                1
# 14  {'classifier:random_forest:max_depth': 'None',...                1
#
#      status
# 0   Unknown
# 1   Unknown
# 2   Unknown
# 3   Unknown
# 4   Unknown
# 5   Unknown
# 6   Unknown
# 7   Unknown
# 8   Unknown
# 9   Unknown
# 10  Unknown
# 11  Unknown
# 12  Unknown
# 13  Unknown
# 14  Unknown
#
# [15 rows x 146 columns]

# %% [markdown]
# Most of the fit times seem to be pushing the upper limit. This clearly needs more time.

# %% [markdown]
# ## Longer time

# %%
model = AutoSklearnClassifier(
    ml_memory_limit=10000,
    time_left_for_this_task=4*24*60*60,
    per_run_time_limit=1*60*60,
    resampling_strategy='cv',
    resampling_strategy_arguments={'folds': 5},
    tmp_folder='autosklearn/classifier_long/tmp/',
    output_folder='autosklearn/classifier_long/out/',
    delete_tmp_folder_after_terminate=False,
    delete_output_folder_after_terminate=False,
    shared_mode=True,
)

# %%
model.fit(x_train, y_train, metric=log_loss, dataset_name='numerai')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-46fb634311ec> in <module>()
# ----> 1 model.fit(x_train, y_train, metric=log_loss, dataset_name='numerai')
#
# /usr/local/lib/python3.5/dist-packages/autosklearn/estimators.py in fit(self, X, y, metric, feat_type, dataset_name)
#     415         return super(AutoSklearnClassifier, self).fit(X=X, y=y, metric=metric,
#     416                                                       feat_type=feat_type,
# --> 417                                                       dataset_name=dataset_name)
#     418
#     419     def predict(self, X, batch_size=None, n_jobs=1):
#
# /usr/local/lib/python3.5/dist-packages/autosklearn/estimators.py in fit(self, *args, **kwargs)
#     314     def fit(self, *args, **kwargs):
#     315         self._automl = self.build_automl()
# --> 316         super(AutoSklearnEstimator, self).fit(*args, **kwargs)
#     317
#     318     def fit_ensemble(self, y, task=None, metric=None, precision='32',
#
# /usr/local/lib/python3.5/dist-packages/autosklearn/estimators.py in fit(self, *args, **kwargs)
#      21
#      22     def fit(self, *args, **kwargs):
# ---> 23         self._automl.fit(*args, **kwargs)
#      24
#      25     def refit(self, X, y):
#
# /usr/local/lib/python3.5/dist-packages/autosklearn/estimators.py in fit(self, X, y, metric, loss, feat_type, dataset_name)
#     556         y = self._process_target_classes(y)
#     557
# --> 558         return self._automl.fit(X, y, task, metric, feat_type, dataset_name)
#     559
#     560     def fit_ensemble(self, y, task=None, metric=None, precision='32',
#
# /usr/local/lib/python3.5/dist-packages/autosklearn/automl.py in fit(self, X, y, task, metric, feat_type, dataset_name)
#     171             raise ValueError('No metric given.')
#     172         if not isinstance(metric, Scorer):
# --> 173             raise ValueError('Metric must be instance of '
#     174                              'autosklearn.metrics.Scorer.')
#     175
#
# ValueError: Metric must be instance of autosklearn.metrics.Scorer.

# %%
with open('autosklearn/classifier_long/model.pkl', 'wb') as auto_sklearn_file:
     pickle.dump(model, auto_sklearn_file)
